# %%
import pandas as pd
df1 = pd.read_csv(r"C:\Users\E1\Downloads\train_data.csv")
df2 = pd.read_csv(r"C:\Users\E1\Downloads\test_data.csv")

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (29165, 20)
# (7292, 20)

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29165 entries, 0 to 29164
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   29165 non-null  int64
#  1   Gender               29165 non-null  object
#  2   Has a car            29165 non-null  object
#  3   Has a property       29165 non-null  object
#  4   Children count       29165 non-null  int64
#  5   Income               29165 non-null  float64
#  6   Employment status    29165 non-null  object
#  7   Education level      29165 non-null  object
#  8   Marital status       29165 non-null  object
#  9   Dwelling             29165 non-null  object
#  10  Age                  29165 non-null  int64
#  11  Employment length    29165 non-null  int64
#  12  Has a mobile phone   29165 non-null  int64
#  13  Has a work phone     29165 non-null  int64
#  14  Has a phone          29165 non-null  int64
# ...

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7292 entries, 0 to 7291
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   7292 non-null   int64
#  1   Gender               7292 non-null   object
#  2   Has a car            7292 non-null   object
#  3   Has a property       7292 non-null   object
#  4   Children count       7292 non-null   int64
#  5   Income               7292 non-null   float64
#  6   Employment status    7292 non-null   object
#  7   Education level      7292 non-null   object
#  8   Marital status       7292 non-null   object
#  9   Dwelling             7292 non-null   object
#  10  Age                  7292 non-null   int64
#  11  Employment length    7292 non-null   int64
#  12  Has a mobile phone   7292 non-null   int64
#  13  Has a work phone     7292 non-null   int64
#  14  Has a phone          7292 non-null   int64
# ...

# %% [markdown]
# # Merge the DataFrames

# %%
df = pd.concat([df1,df2], ignore_index="True")

# %%
df.head()
# Out:
#         ID Gender Has a car Has a property  Children count    Income  \
# 0  5037048      M         Y              Y               0  135000.0
# 1  5044630      F         Y              N               1  135000.0
# 2  5079079      F         N              Y               2  180000.0
# 3  5112872      F         Y              Y               0  360000.0
# 4  5105858      F         N              N               0  270000.0
#
#       Employment status                Education level        Marital status  \
# 0               Working  Secondary / secondary special               Married
# 1  Commercial associate               Higher education  Single / not married
# 2  Commercial associate  Secondary / secondary special               Married
# 3  Commercial associate               Higher education  Single / not married
# 4               Working  Secondary / secondary special             Separated
#
#             Dwelling    Age  Employment length  Has a mobile phone  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#                  ID  Children count        Income           Age  \
# count  3.645700e+04    36457.000000  3.645700e+04  36457.000000
# mean   5.078227e+06        0.430315  1.866857e+05 -15975.173382
# std    4.187524e+04        0.742367  1.017892e+05   4200.549944
# min    5.008804e+06        0.000000  2.700000e+04 -25152.000000
# 25%    5.042028e+06        0.000000  1.215000e+05 -19438.000000
# 50%    5.074614e+06        0.000000  1.575000e+05 -15563.000000
# 75%    5.115396e+06        1.000000  2.250000e+05 -12462.000000
# max    5.150487e+06       19.000000  1.575000e+06  -7489.000000
#
#        Employment length  Has a mobile phone  Has a work phone   Has a phone  \
# count       36457.000000             36457.0      36457.000000  36457.000000
# mean        59262.935568                 1.0          0.225526      0.294813
# std        137651.334859                 0.0          0.417934      0.455965
# min        -15713.000000                 1.0          0.000000      0.000000
# ...

# %%
print(df.shape)
# Out:
# (36457, 20)

# %%
# Check the datatypes 
df.dtypes
# Out:
# ID                       int64
# Gender                  object
# Has a car               object
# Has a property          object
# Children count           int64
# Income                 float64
# Employment status       object
# Education level         object
# Marital status          object
# Dwelling                object
# Age                      int64
# Employment length        int64
# Has a mobile phone       int64
# Has a work phone         int64
# Has a phone              int64
# Has an email             int64
# Job title               object
# Family member count      int64
# Account age              int64
# Is high risk             int64
# dtype: object

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    24430
# M    12027
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Gender', data=df)
plt.xticks(rotation=45)
plt.title("Countplot Showing Number of MALE and FEMALE")
plt.show()

# %%
df["Education level"].unique()
# Out:
# array(['Secondary / secondary special', 'Higher education',
#        'Lower secondary', 'Incomplete higher', 'Academic degree'],
#       dtype=object)

# %%
# Explore key factors
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Job title', data=df)
plt.xticks(rotation=90)
plt.title("Bar chart showing the count of applicants by employment status")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your dataset is loaded into a DataFrame called 'df'

# Box plot of income distribution across different education levels
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Education level', y='Income')
plt.title('Income Distribution Across Different Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Income')
plt.xticks(rotation=15)  # Rotate x-axis labels for better readability
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Has a car', data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='Has a car', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Employment status', data=df)
plt.xticks(rotation=90)
plt.show()

# %%
# 1.3 Conduct univariate analysis
# Visualize the distribution of numerical features using histograms
for col in ['Income', 'Age', 'Children count']:
    sns.histplot(df[col], bins=20)
    plt.title(f' Histogram of {col} Distribution')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
# 1.4 Conduct bivariate analysis
# Explore relationships between numerical features and the target variable using scatter plots or box plots
sns.boxplot(x='Is high risk', y='Income', data=df)
plt.title('Income vs. Credit Card Approval')
plt.xlabel('Is high risk')
plt.ylabel('Income')
plt.show()

# %%
# 1.5 Explore key factors
# Visualize counts of 'Gender' and 'Is high risk' using stacked bar plot
gender_approval = pd.crosstab(df['Gender'], df['Is high risk'])
gender_approval.plot(kind='bar', stacked=True)
plt.title('Gender vs. Credit Card Approval')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot of income versus age
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='Income', alpha=0.5)
plt.title('Scatter Plot of Income versus Age')
plt.xlabel('Age')
plt.ylabel('Income')
plt.grid(True)
plt.show()

# %%
# Heatmap of correlation matrix between numerical variables
numerical_variables = ['Income', 'Age', 'Employment length', 'Children count', 'Family member count', 'Account age']
correlation_matrix = df[numerical_variables].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
Feature Engineering

# %%
df.groupby('Gender')['Is high risk'].mean()
# Out:
# Gender
# F    0.015514
# M    0.019706
# Name: Is high risk, dtype: float64

# %%
df.groupby('Job title')['Is high risk'].mean()
# Out:
# Job title
# Accountants              0.018533
# Cleaning staff           0.009074
# Cooking staff            0.013740
# Core staff               0.020607
# Drivers                  0.022919
# HR staff                 0.011765
# High skill tech staff    0.021692
# IT staff                 0.050000
# Laborers                 0.015939
# Low-skill Laborers       0.045714
# Managers                 0.015604
# Medicine staff           0.008285
# Private service staff    0.005814
# Realty agents            0.000000
# Sales staff              0.012912
# Secretaries              0.013245
# Security staff           0.021959
# Unknown                  0.017133
# Waiters/barmen staff     0.011494
# Name: Is high risk, dtype: float64

# %%
df.groupby('Job title')['Income'].mean()
# Out:
# Job title
# Accountants              202463.865834
# Cleaning staff           149141.107078
# Cooking staff            146517.251908
# Core staff               190172.786967
# Drivers                  209797.240412
# HR staff                 193764.705882
# High skill tech staff    196053.579176
# IT staff                 199860.000000
# Laborers                 179794.282402
# Low-skill Laborers       133920.000000
# Managers                 279117.292829
# Medicine staff           166114.618061
# Private service staff    198863.372093
# Realty agents            247500.000000
# Sales staff              174984.897848
# Secretaries              168079.470199
# Security staff           177037.753378
# Unknown                  168599.123819
# Waiters/barmen staff     156206.896552
# Name: Income, dtype: float64

# %%
# Calculate average income per year of employment
df['Average_Income_Per_Year'] = df['Income'] / df['Employment length']

# Display the first few rows of the DataFrame to verify the new feature
print(df[['Income', 'Employment length', 'Average_Income_Per_Year']].head())
# Out:
#      Income  Employment length  Average_Income_Per_Year
# 0  135000.0              -3111               -43.394407
# 1  135000.0              -1651               -81.768625
# 2  180000.0              -5657               -31.818985
# 3  360000.0              -2046              -175.953079
# 4  270000.0               -515              -524.271845

# %%
df['Income_Age_interaction'] = df['Income'] * df['Age']

# %% [markdown]
# # Data preprocessing

# %%
# Missing Values Handeling
df['Job title'].fillna('Unknown', inplace=True)

# %%
# Encoding catogorical values
df = pd.get_dummies(df, columns=['Gender',"Has a car","Has a property"], drop_first=True, dtype="int")

# %%
# Scale or normalize numerical features
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df['Income'] = scaler.fit_transform(df[['Income']])

# %%
scaler = MinMaxScaler()
df['Age'] = scaler.fit_transform(df[['Age']])

# %%
scaler = MinMaxScaler()
df['Employment length'] = scaler.fit_transform(df[['Employment length']])

# %%
scaler = MinMaxScaler()
df['Account age'] = scaler.fit_transform(df[['Account age']])

# %%
df.sample(2)
# Out:
#        Children count  Education level       Age  Employment length  \
# 14424               0              3.0  0.781238           0.035167
# 27974               0              1.0  0.615071           0.038942
#
#        Has a mobile phone  Has a work phone  Has a phone  Has an email  \
# 14424                   1                 0            0             1
# 27974                   1                 0            0             0
#
#        Family member count  Account age  ...  Job title_Low-skill Laborers  \
# 14424                    2         0.25  ...                             0
# 27974                    1         0.55  ...                             0
#
#        Job title_Managers  Job title_Medicine staff  \
# 14424                   0                         0
# 27974                   0                         0
#
#        Job title_Private service staff  Job title_Realty agents  \
# 14424                                0                        0
# ...

# %%
# Encoding catogorical values
df=pd.get_dummies(df, columns=["Employment status","Marital status","Dwelling","Job title"], drop_first = True, dtype="int")

# %%
df.sample(2)
# Out:
#             ID  Children count    Income                Education level  \
# 423    5085648               1  0.040698  Secondary / secondary special
# 24809  5022410               0  0.081395               Higher education
# 6036   5096931               0  0.034884  Secondary / secondary special
# 1855   5022585               0  0.113372  Secondary / secondary special
# 27062  5066467               0  0.069767  Secondary / secondary special
# 20697  5094969               2  0.021802               Higher education
# 15691  5143019               0  0.156977  Secondary / secondary special
#
#             Age  Employment length  Has a mobile phone  Has a work phone  \
# 423    0.726717           0.040482                   1                 0
# 24809  0.184170           1.000000                   1                 0
# 6036   0.239597           1.000000                   1                 0
# 1855   0.416067           0.014789                   1                 0
# ...

# %%
df.drop(columns=["ID","Income"], inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder

# Initialize the OrdinalEncoder
ordinal_encoder = OrdinalEncoder(categories=[['Lower secondary', 'Secondary / secondary special', 'Incomplete higher', 'Higher education', 'Academic degree']])

# Fit and transform the 'Education level' column
df['Education level'] = ordinal_encoder.fit_transform(df[['Education level']])

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X = df.drop(['Is high risk'], axis=1)
y = df['Is high risk']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# Train various machine learning models for classification
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier()
}

for name, model in models.items():
    model.fit(X_train, y_train)

# %%
# 4.3 Evaluate model performance
from sklearn.metrics import accuracy_score

for name, model in models.items():
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f'{name}: Accuracy = {accuracy}')
# Out:
# Logistic Regression: Accuracy = 0.9830864874748583
# Decision Tree: Accuracy = 0.9723898336076066
# Random Forest: Accuracy = 0.9818065459864692

# %%
# Evaluate model performance
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# Assuming best_model is the selected model
y_pred = best_model.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# Print evaluation metrics
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"ROC AUC Score: {roc_auc}")
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# Accuracy: 0.981440848418358
# Precision: 0.3392857142857143
# Recall: 0.10270270270270271
# F1 Score: 0.15767634854771787
# ROC AUC Score: 0.5496309012444045
# Confusion Matrix:
# [[10716    37]
#  [  166    19]]

# %%
# Use the best-performing model to predict credit card approval
best_model = RandomForestClassifier() 
best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

# Understand feature importance
feature_importance = pd.Series(best_model.feature_importances_, index=X.columns)
print(feature_importance)
# Out:
# Children count                         0.020813
# Education level                        0.023679
# Age                                    0.158512
# Employment length                      0.114559
# Has a mobile phone                     0.000000
# Has a work phone                       0.014813
# Has a phone                            0.018047
# Has an email                           0.009464
# Family member count                    0.029759
# Account age                            0.245973
# Income_Age_interaction                 0.153535
# Gender_M                               0.017426
# Has a car_Y                            0.018660
# Has a property_Y                       0.018675
# Employment status_Pensioner            0.015906
# Employment status_State servant        0.004698
# Employment status_Student              0.000008
# Employment status_Working              0.016493
# Marital status_Married                 0.011912
# Marital status_Separated               0.004965
# ...

# %%
import matplotlib.pyplot as plt

high_risk_count = sum(y_pred)  # Count of high-risk applicants
low_risk_count = len(y_pred) - high_risk_count  # Count of low-risk applicants

# Data for the pie chart
sizes = [high_risk_count, low_risk_count]
labels = ['High Risk', 'Low Risk']
colors = ['#d62728', '#2ca02c']  # Red for High Risk, Green for Low Risk

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of High-Risk and Low-Risk Applicants')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
top_features = sorted(feature_importance.items(), key=lambda x: x[1], reverse=True)[:5]

# top features
print("\nTop Features:")
for feature, importance in top_features:
    print(f"{feature}: Importance = {importance}")

# Recommendations based on insights:
print("\nRecommendations:")
print("- Consider focusing on features with higher importance such as 'Age' and 'Account age'.")
print("- Pay attention to 'Income_Age_interaction', which seems to have significant impact.")
print("- Further analysis can be done on 'Employment length' and 'Education level' to understand their influence.")
# Out:
# Top Features:
# Account age: Importance = 0.24597330744810827
# Age: Importance = 0.15851161243910905
# Income_Age_interaction: Importance = 0.15353523195229607
# Employment length: Importance = 0.11455893149068053
# Family member count: Importance = 0.029758999690757914
#
# Recommendations:
# - Consider focusing on features with higher importance such as 'Age' and 'Account age'.
# - Pay attention to 'Income_Age_interaction', which seems to have significant impact.
# - Further analysis can be done on 'Employment length' and 'Education level' to understand their influence.
